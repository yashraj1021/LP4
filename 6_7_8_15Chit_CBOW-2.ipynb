# %%
file_path = r"D:\Deep_Learning_code\LP-IV-datasets\CBOW\CBOW.txt"

with open(file_path, 'r') as file:
    file_contents = file.read()

# %%
file_contents
# Out:
# 'The speed of transmission is an important point of difference between the two viruses. Influenza has a shorter median incubation period (the time from infection to appearance of symptoms) and a shorter serial interval (the time between successive cases) than COVID-19 virus. The serial interval for COVID-19 virus is estimated to be 5-6 days, while for influenza virus, the serial interval is 3 days. This means that influenza can spread faster than COVID-19. \n\nFurther, transmission in the first 3-5 days of illness, or potentially pre-symptomatic transmission â€“transmission of the virus before the appearance of symptoms â€“ is a major driver of transmission for influenza. In contrast, while we are learning that there are people who can shed COVID-19 virus 24-48 hours prior to symptom onset, at present, this does not appear to be a major driver of transmission. \n\nThe reproductive number â€“ the number of secondary infections generated from one infected individual â€“ is understood to be between 2 and 2.5 for COVID-19 virus, higher than for influenza. However, estimates for both COVID-19 and influenza viruses are very context and time-specific, making direct comparisons more difficult.  '

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import GlobalAveragePooling1D, Embedding, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics.pairwise import cosine_similarity

# %%
sentences = file_contents.split('.')

# Tokenize the sentences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
total_words = len(tokenizer.word_index) + 1

# Generate context-target pairs for training
window_size = 3
tokenized_sentences = tokenizer.texts_to_sequences(sentences)

data, labels = [], []
for sentence in tokenized_sentences:
    for i, target_word in enumerate(sentence):
        context = [
            sentence[j] for j in range(i - window_size, i + window_size + 1)
            if j != i and 0 <= j < len(sentence)
        ]
        data.append(context)
        labels.append(target_word)

# Convert data and labels to numpy arrays
data = pad_sequences(data)
labels = np.array(labels)

# %%
# model = models.Sequential([
#     layers.Embedding(input_dim=total_words, output_dim=50, input_length=window_size * 2),
#     layers.GlobalAveragePooling1D(),
#     layers.Dense(total_words, activation='softmax')
# ])

# %%
model = Sequential()
model.add(Embedding(input_dim = total_words, output_dim = 50, input_length = window_size*2))
model.add(GlobalAveragePooling1D())
model.add(Dense(total_words, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 6, 50)             5150
#
#  global_average_pooling1d_1   (None, 50)               0
#  (GlobalAveragePooling1D)
#
#  dense_1 (Dense)             (None, 103)               5253
#
# =================================================================
# Total params: 10,403
# Trainable params: 10,403
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(data, labels, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.6353 - accuracy: 0.0051
# Epoch 2/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.6259 - accuracy: 0.0758
# Epoch 3/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.6185 - accuracy: 0.1263
# Epoch 4/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.6110 - accuracy: 0.1667
# Epoch 5/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.6038 - accuracy: 0.1869
# Epoch 6/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.5960 - accuracy: 0.1970
# Epoch 7/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.5883 - accuracy: 0.2071
# Epoch 8/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.5799 - accuracy: 0.2222
# Epoch 9/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.5708 - accuracy: 0.2222
# Epoch 10/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.5611 - accuracy: 0.2273
# Epoch 11/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.5507 - accuracy: 0.2323
# Epoch 12/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.5397 - accuracy: 0.2273
# Epoch 13/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.5275 - accuracy: 0.2222
# Epoch 14/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.5150 - accuracy: 0.2273
# Epoch 15/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.5006 - accuracy: 0.2121
# Epoch 16/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.4858 - accuracy: 0.2222
# Epoch 17/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.4693 - accuracy: 0.2121
# Epoch 18/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.4516 - accuracy: 0.2172
# Epoch 19/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.4324 - accuracy: 0.2121
# Epoch 20/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.4128 - accuracy: 0.2172
# Epoch 21/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.3914 - accuracy: 0.2121
# Epoch 22/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.3687 - accuracy: 0.2121
# Epoch 23/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.3447 - accuracy: 0.2071
# Epoch 24/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.3198 - accuracy: 0.2172
# Epoch 25/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.2930 - accuracy: 0.2222
# Epoch 26/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.2657 - accuracy: 0.2121
# Epoch 27/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.2367 - accuracy: 0.2222
# Epoch 28/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.2080 - accuracy: 0.2323
# Epoch 29/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.1777 - accuracy: 0.2374
# Epoch 30/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.1471 - accuracy: 0.2323
# Epoch 31/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.1152 - accuracy: 0.2323
# Epoch 32/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.0832 - accuracy: 0.2374
# Epoch 33/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.0512 - accuracy: 0.2374
# Epoch 34/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.0177 - accuracy: 0.2424
# Epoch 35/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.9840 - accuracy: 0.2475
# Epoch 36/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.9511 - accuracy: 0.2475
# Epoch 37/200
# 7/7 [==============================] - 0s 1ms/step - loss: 3.9166 - accuracy: 0.2374
# Epoch 38/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.8834 - accuracy: 0.2424
# Epoch 39/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.8496 - accuracy: 0.2374
# Epoch 40/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.8160 - accuracy: 0.2323
# Epoch 41/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.7827 - accuracy: 0.2323
# Epoch 42/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.7498 - accuracy: 0.2475
# Epoch 43/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.7172 - accuracy: 0.2576
# Epoch 44/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.6854 - accuracy: 0.2576
# Epoch 45/200
# 7/7 [==============================] - 0s 1ms/step - loss: 3.6527 - accuracy: 0.2576
# Epoch 46/200
# 7/7 [==============================] - 0s 1ms/step - loss: 3.6220 - accuracy: 0.2576
# Epoch 47/200
# 7/7 [==============================] - 0s 1ms/step - loss: 3.5907 - accuracy: 0.2525
# Epoch 48/200
# 7/7 [==============================] - 0s 1ms/step - loss: 3.5599 - accuracy: 0.2475
# Epoch 49/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.5302 - accuracy: 0.2323
# Epoch 50/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.5004 - accuracy: 0.2273
# Epoch 51/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.4698 - accuracy: 0.2273
# Epoch 52/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.4405 - accuracy: 0.2222
# Epoch 53/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.4122 - accuracy: 0.2273
# Epoch 54/200
# 7/7 [==============================] - 0s 1ms/step - loss: 3.3829 - accuracy: 0.2273
# Epoch 55/200
# 7/7 [==============================] - 0s 3ms/step - loss: 3.3551 - accuracy: 0.2273
# Epoch 56/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.3269 - accuracy: 0.2374
# Epoch 57/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.2994 - accuracy: 0.2424
# Epoch 58/200
# 7/7 [==============================] - 0s 1ms/step - loss: 3.2726 - accuracy: 0.2424
# Epoch 59/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.2452 - accuracy: 0.2525
# Epoch 60/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.2181 - accuracy: 0.2525
# Epoch 61/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.1915 - accuracy: 0.2525
# Epoch 62/200
# 7/7 [==============================] - 0s 1ms/step - loss: 3.1655 - accuracy: 0.2576
# Epoch 63/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.1398 - accuracy: 0.2677
# Epoch 64/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.1141 - accuracy: 0.2727
# Epoch 65/200
# 7/7 [==============================] - 0s 1ms/step - loss: 3.0891 - accuracy: 0.2677
# Epoch 66/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.0640 - accuracy: 0.2727
# Epoch 67/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.0389 - accuracy: 0.2727
# Epoch 68/200
# 7/7 [==============================] - 0s 2ms/step - loss: 3.0148 - accuracy: 0.2727
# Epoch 69/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.9905 - accuracy: 0.2626
# Epoch 70/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.9665 - accuracy: 0.2626
# Epoch 71/200
# 7/7 [==============================] - 0s 1ms/step - loss: 2.9424 - accuracy: 0.2677
# Epoch 72/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.9188 - accuracy: 0.2778
# Epoch 73/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.8944 - accuracy: 0.2879
# Epoch 74/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.8708 - accuracy: 0.2828
# Epoch 75/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.8478 - accuracy: 0.2929
# Epoch 76/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.8243 - accuracy: 0.3030
# Epoch 77/200
# 7/7 [==============================] - 0s 1ms/step - loss: 2.8016 - accuracy: 0.3030
# Epoch 78/200
# 7/7 [==============================] - 0s 1ms/step - loss: 2.7786 - accuracy: 0.3131
# Epoch 79/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.7565 - accuracy: 0.3182
# Epoch 80/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.7348 - accuracy: 0.3232
# Epoch 81/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.7128 - accuracy: 0.3333
# Epoch 82/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.6912 - accuracy: 0.3434
# Epoch 83/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.6693 - accuracy: 0.3434
# Epoch 84/200
# 7/7 [==============================] - 0s 1ms/step - loss: 2.6476 - accuracy: 0.3485
# Epoch 85/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.6271 - accuracy: 0.3636
# Epoch 86/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.6055 - accuracy: 0.3687
# Epoch 87/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.5857 - accuracy: 0.3788
# Epoch 88/200
# 7/7 [==============================] - 0s 918us/step - loss: 2.5653 - accuracy: 0.3788
# Epoch 89/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.5444 - accuracy: 0.3838
# Epoch 90/200
# 7/7 [==============================] - 0s 980us/step - loss: 2.5251 - accuracy: 0.3838
# Epoch 91/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.5053 - accuracy: 0.3838
# Epoch 92/200
# 7/7 [==============================] - 0s 1ms/step - loss: 2.4859 - accuracy: 0.3838
# Epoch 93/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4662 - accuracy: 0.3838
# Epoch 94/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4468 - accuracy: 0.3939
# Epoch 95/200
# 7/7 [==============================] - 0s 1ms/step - loss: 2.4279 - accuracy: 0.3990
# Epoch 96/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4093 - accuracy: 0.4091
# Epoch 97/200
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3901 - accuracy: 0.4091
# Epoch 98/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3719 - accuracy: 0.4141
# Epoch 99/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3534 - accuracy: 0.4141
# Epoch 100/200
# 7/7 [==============================] - 0s 591us/step - loss: 2.3352 - accuracy: 0.4192
# Epoch 101/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3174 - accuracy: 0.4242
# Epoch 102/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3000 - accuracy: 0.4242
# Epoch 103/200
# 7/7 [==============================] - 0s 1ms/step - loss: 2.2826 - accuracy: 0.4242
# Epoch 104/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2652 - accuracy: 0.4293
# Epoch 105/200
# 7/7 [==============================] - 0s 589us/step - loss: 2.2480 - accuracy: 0.4495
# Epoch 106/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2312 - accuracy: 0.4444
# Epoch 107/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2141 - accuracy: 0.4545
# Epoch 108/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1972 - accuracy: 0.4697
# Epoch 109/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1810 - accuracy: 0.4798
# Epoch 110/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1648 - accuracy: 0.4848
# Epoch 111/200
# 7/7 [==============================] - 0s 918us/step - loss: 2.1490 - accuracy: 0.4949
# Epoch 112/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1337 - accuracy: 0.5051
# Epoch 113/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1178 - accuracy: 0.5101
# Epoch 114/200
# 7/7 [==============================] - 0s 907us/step - loss: 2.1016 - accuracy: 0.5202
# Epoch 115/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0859 - accuracy: 0.5253
# Epoch 116/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0707 - accuracy: 0.5303
# Epoch 117/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0548 - accuracy: 0.5404
# Epoch 118/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0403 - accuracy: 0.5606
# Epoch 119/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0243 - accuracy: 0.5606
# Epoch 120/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0093 - accuracy: 0.5657
# Epoch 121/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.9949 - accuracy: 0.5707
# Epoch 122/200
# 7/7 [==============================] - 0s 766us/step - loss: 1.9790 - accuracy: 0.5758
# Epoch 123/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9643 - accuracy: 0.5909
# Epoch 124/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9493 - accuracy: 0.6061
# Epoch 125/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9345 - accuracy: 0.6162
# Epoch 126/200
# 7/7 [==============================] - 0s 591us/step - loss: 1.9196 - accuracy: 0.6263
# Epoch 127/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9059 - accuracy: 0.6263
# Epoch 128/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8915 - accuracy: 0.6212
# Epoch 129/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8773 - accuracy: 0.6212
# Epoch 130/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8637 - accuracy: 0.6263
# Epoch 131/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.8499 - accuracy: 0.6364
# Epoch 132/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8366 - accuracy: 0.6465
# Epoch 133/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8223 - accuracy: 0.6515
# Epoch 134/200
# 7/7 [==============================] - 0s 907us/step - loss: 1.8090 - accuracy: 0.6566
# Epoch 135/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7953 - accuracy: 0.6667
# Epoch 136/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.7821 - accuracy: 0.6717
# Epoch 137/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.7681 - accuracy: 0.6768
# Epoch 138/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7548 - accuracy: 0.6768
# Epoch 139/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7414 - accuracy: 0.6768
# Epoch 140/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.7287 - accuracy: 0.6869
# Epoch 141/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7163 - accuracy: 0.6919
# Epoch 142/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7041 - accuracy: 0.6919
# Epoch 143/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6912 - accuracy: 0.6970
# Epoch 144/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6781 - accuracy: 0.6970
# Epoch 145/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6661 - accuracy: 0.7071
# Epoch 146/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6536 - accuracy: 0.7071
# Epoch 147/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6415 - accuracy: 0.7121
# Epoch 148/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6295 - accuracy: 0.7121
# Epoch 149/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6165 - accuracy: 0.7121
# Epoch 150/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6052 - accuracy: 0.7121
# Epoch 151/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5925 - accuracy: 0.7172
# Epoch 152/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5796 - accuracy: 0.7222
# Epoch 153/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5676 - accuracy: 0.7222
# Epoch 154/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5560 - accuracy: 0.7374
# Epoch 155/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5440 - accuracy: 0.7374
# Epoch 156/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5319 - accuracy: 0.7525
# Epoch 157/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5198 - accuracy: 0.7576
# Epoch 158/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5085 - accuracy: 0.7626
# Epoch 159/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4971 - accuracy: 0.7677
# Epoch 160/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4857 - accuracy: 0.7727
# Epoch 161/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4740 - accuracy: 0.7778
# Epoch 162/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4633 - accuracy: 0.7778
# Epoch 163/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4513 - accuracy: 0.7879
# Epoch 164/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4401 - accuracy: 0.7879
# Epoch 165/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4292 - accuracy: 0.7828
# Epoch 166/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4178 - accuracy: 0.7828
# Epoch 167/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4074 - accuracy: 0.7879
# Epoch 168/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3963 - accuracy: 0.8030
# Epoch 169/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3857 - accuracy: 0.7980
# Epoch 170/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3745 - accuracy: 0.7980
# Epoch 171/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3636 - accuracy: 0.8081
# Epoch 172/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3537 - accuracy: 0.8232
# Epoch 173/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3426 - accuracy: 0.8283
# Epoch 174/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3321 - accuracy: 0.8283
# Epoch 175/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3220 - accuracy: 0.8283
# Epoch 176/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3118 - accuracy: 0.8333
# Epoch 177/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3017 - accuracy: 0.8333
# Epoch 178/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2913 - accuracy: 0.8384
# Epoch 179/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2812 - accuracy: 0.8384
# Epoch 180/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2711 - accuracy: 0.8485
# Epoch 181/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2613 - accuracy: 0.8535
# Epoch 182/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2513 - accuracy: 0.8485
# Epoch 183/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2407 - accuracy: 0.8586
# Epoch 184/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2312 - accuracy: 0.8535
# Epoch 185/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2214 - accuracy: 0.8535
# Epoch 186/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2112 - accuracy: 0.8586
# Epoch 187/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2022 - accuracy: 0.8586
# Epoch 188/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1920 - accuracy: 0.8586
# Epoch 189/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1827 - accuracy: 0.8737
# Epoch 190/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1725 - accuracy: 0.8737
# Epoch 191/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1629 - accuracy: 0.8737
# Epoch 192/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1535 - accuracy: 0.8788
# Epoch 193/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1441 - accuracy: 0.8788
# Epoch 194/200
# 7/7 [==============================] - 0s 335us/step - loss: 1.1345 - accuracy: 0.8838
# Epoch 195/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1253 - accuracy: 0.8889
# Epoch 196/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1153 - accuracy: 0.8939
# Epoch 197/200
# 7/7 [==============================] - 0s 843us/step - loss: 1.1063 - accuracy: 0.8939
# Epoch 198/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0974 - accuracy: 0.8939
# Epoch 199/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0880 - accuracy: 0.8939
# Epoch 200/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0792 - accuracy: 0.8939

# %%
word_embeddings = model.layers[0].get_weights()[0]

# %%
from sklearn.metrics.pairwise import cosine_similarity

target_word = 'influenza'
target_embedding = word_embeddings[tokenizer.word_index[target_word]]

similarities = cosine_similarity(target_embedding.reshape(1, -1), word_embeddings)[0]
most_similar_indices = similarities.argsort()[-5:][::-1]
    
most_similar_words = [word for word, idx in tokenizer.word_index.items() if idx in most_similar_indices]

print(f"Most similar words to '{target_word}': {most_similar_words}")
# Out:
# Most similar words to 'influenza': ['influenza', '3', 'difference', 'we', 'present']
